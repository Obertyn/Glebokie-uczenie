# %%
'''Trains a simple deep NN on the MNIST dataset.

Gets to 99.6% test accuracy after 40 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''

from __future__ import print_function

import matplotlib.pyplot as plt
import numpy as np

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.optimizers import RMSprop, Adam, Adadelta
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.vis_utils import plot_model
from IPython.display import Image 
from keras.callbacks import EarlyStopping

batch_size = 128
num_classes = 10
epochs = 40

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train0), (x_test, y_test0) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

! pip install optuna

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train0, num_classes)
y_test = keras.utils.to_categorical(y_test0, num_classes)

N_TRAIN_EXAMPLES=800
N_TEST_EXAMPLES=10000

x_train=x_train[:N_TRAIN_EXAMPLES]
x_test=x_test[:N_TEST_EXAMPLES]
y_train=y_train[:N_TRAIN_EXAMPLES]
y_test=y_test[:N_TEST_EXAMPLES]

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.6/dist-packages (2.4.0)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: cmaes>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (0.7.0)
# Requirement already satisfied: cliff in /usr/local/lib/python3.6/dist-packages (from optuna) (3.6.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.3.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from optuna) (4.41.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.6/dist-packages (from optuna) (4.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from optuna) (1.19.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from optuna) (1.0.0)
# Requirement already satisfied: alembic in /usr/local/lib/python3.6/dist-packages (from optuna) (1.5.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (20.8)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (5.5.1)
# Requirement already satisfied: PrettyTable<0.8,>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (0.7.2)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: cmd2!=0.8.3,>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (1.4.0)
# Requirement already satisfied: pyparsing>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (2.4.7)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.13)
# Requirement already satisfied: Mako in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (1.1.4)
# Requirement already satisfied: python-editor>=0.3 in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (1.0.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (2.8.1)
# Requirement already satisfied: importlib-metadata>=1.7.0; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from stevedore>=2.0.1->cliff->optuna) (3.3.0)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (20.3.0)
# Requirement already satisfied: colorama>=0.3.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (0.4.4)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (1.8.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic->optuna) (1.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil->alembic->optuna) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.7.0; python_version < "3.8"->stevedore>=2.0.1->cliff->optuna) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.7.0; python_version < "3.8"->stevedore>=2.0.1->cliff->optuna) (3.7.4.3)
# 800 train samples
# 10000 test samples

# %%
#visualize the digits

fig = plt.figure(figsize=(10, 10))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(100):
    ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(x_train[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')
    # label the image with the target value
    ax.text(0, 7, str(y_train0[i]))

# %%
# set up image augmentation
datagen = ImageDataGenerator( 
    rotation_range=30,
    horizontal_flip=False,
    vertical_flip=False,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.15
    )
datagen.fit(x_train)

# %%
# see example augmentation images

fig = plt.figure(figsize=(12, 12))
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    for i in range(0, 9):
         plt.subplot(330 + 1 + i)
         plt.imshow(X_batch[i].reshape(img_rows,img_cols),cmap=plt.cm.binary, interpolation='nearest')
         plt.axis('off')
    plt.show()
    break

# %%
# see example augmentation images
fig = plt.figure(figsize=(12, 12))

for i in range(0, 25):
    for X_batch, y_batch in datagen.flow(x_train[4:7], y_train[4:7], batch_size=1, shuffle=False):
         plt.subplot(5,5,i+1)
         plt.imshow(X_batch[0].reshape(img_rows,img_cols),cmap=plt.cm.binary, interpolation='nearest')
         plt.axis('off')
         break

plt.show()

# %%
# Our old fully connected (dense) network
#model = Sequential()
#model.add(Dense(512, activation='relu', input_shape=(784,)))
#model.add(Dropout(0.2))
#model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(num_classes, activation='softmax'))

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))



model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               131200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 225,162
# Trainable params: 225,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
Image('model_plot.png')

# %%
0
model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

es = EarlyStopping(monitor = 'val_accuracy', patience =12, verbose=1)

history = model.fit(datagen.flow(x_train, y_train,batch_size=batch_size),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test),
                    callbacks = [es])
# Out:
# Epoch 1/40
# 7/7 [==============================] - 11s 2s/step - loss: 2.2917 - accuracy: 0.1298 - val_loss: 2.1955 - val_accuracy: 0.4202
# Epoch 2/40
# 7/7 [==============================] - 10s 2s/step - loss: 2.2518 - accuracy: 0.1675 - val_loss: 2.0016 - val_accuracy: 0.4287
# Epoch 3/40
# 7/7 [==============================] - 10s 2s/step - loss: 2.1709 - accuracy: 0.2152 - val_loss: 1.7090 - val_accuracy: 0.5892
# Epoch 4/40
# 7/7 [==============================] - 10s 2s/step - loss: 2.0279 - accuracy: 0.2917 - val_loss: 1.4233 - val_accuracy: 0.6359
# Epoch 5/40
# 7/7 [==============================] - 10s 2s/step - loss: 1.8511 - accuracy: 0.3673 - val_loss: 1.1225 - val_accuracy: 0.7313
# Epoch 6/40
# 7/7 [==============================] - 10s 2s/step - loss: 1.7116 - accuracy: 0.4310 - val_loss: 0.8959 - val_accuracy: 0.7938
# Epoch 7/40
# 7/7 [==============================] - 10s 2s/step - loss: 1.5967 - accuracy: 0.4467 - val_loss: 0.8123 - val_accuracy: 0.7999
# Epoch 8/40
# 7/7 [==============================] - 10s 2s/step - loss: 1.4567 - accuracy: 0.5192 - val_loss: 0.5923 - val_accuracy: 0.8574
# Epoch 9/40
# 7/7 [==============================] - 10s 2s/step - loss: 1.3871 - accuracy: 0.5400 - val_loss: 0.5184 - val_accuracy: 0.8852
# Epoch 10/40
# 7/7 [==============================] - 10s 2s/step - loss: 1.2485 - accuracy: 0.5888 - val_loss: 0.4203 - val_accuracy: 0.8999
# Epoch 11/40
# 7/7 [==============================] - 10s 2s/step - loss: 1.1593 - accuracy: 0.6194 - val_loss: 0.3556 - val_accuracy: 0.9158
# Epoch 12/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.9984 - accuracy: 0.6911 - val_loss: 0.3490 - val_accuracy: 0.9103
# Epoch 13/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.9888 - accuracy: 0.6691 - val_loss: 0.3087 - val_accuracy: 0.9191
# Epoch 14/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.8832 - accuracy: 0.7011 - val_loss: 0.2662 - val_accuracy: 0.9244
# Epoch 15/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.8814 - accuracy: 0.7411 - val_loss: 0.2672 - val_accuracy: 0.9307
# Epoch 16/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.8649 - accuracy: 0.7250 - val_loss: 0.2555 - val_accuracy: 0.9287
# Epoch 17/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.8198 - accuracy: 0.7299 - val_loss: 0.2543 - val_accuracy: 0.9241
# Epoch 18/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.8335 - accuracy: 0.7420 - val_loss: 0.2510 - val_accuracy: 0.9280
# Epoch 19/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.7249 - accuracy: 0.7662 - val_loss: 0.2114 - val_accuracy: 0.9355
# Epoch 20/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.7414 - accuracy: 0.7598 - val_loss: 0.2056 - val_accuracy: 0.9377
# Epoch 21/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.5864 - accuracy: 0.8246 - val_loss: 0.1811 - val_accuracy: 0.9452
# Epoch 22/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.6418 - accuracy: 0.7838 - val_loss: 0.1727 - val_accuracy: 0.9456
# Epoch 23/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.6468 - accuracy: 0.7855 - val_loss: 0.1755 - val_accuracy: 0.9437
# Epoch 24/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.5423 - accuracy: 0.8183 - val_loss: 0.1803 - val_accuracy: 0.9453
# Epoch 25/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.5690 - accuracy: 0.8322 - val_loss: 0.1650 - val_accuracy: 0.9490
# Epoch 26/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.6349 - accuracy: 0.7968 - val_loss: 0.1405 - val_accuracy: 0.9556
# Epoch 27/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.5085 - accuracy: 0.8372 - val_loss: 0.1629 - val_accuracy: 0.9483
# Epoch 28/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.5636 - accuracy: 0.8161 - val_loss: 0.1484 - val_accuracy: 0.9534
# Epoch 29/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.5568 - accuracy: 0.8332 - val_loss: 0.1791 - val_accuracy: 0.9420
# Epoch 30/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.5018 - accuracy: 0.8467 - val_loss: 0.1494 - val_accuracy: 0.9544
# Epoch 31/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.4965 - accuracy: 0.8605 - val_loss: 0.1425 - val_accuracy: 0.9534
# Epoch 32/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.5161 - accuracy: 0.8331 - val_loss: 0.1419 - val_accuracy: 0.9529
# Epoch 33/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.4957 - accuracy: 0.8307 - val_loss: 0.1334 - val_accuracy: 0.9567
# Epoch 34/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.4319 - accuracy: 0.8604 - val_loss: 0.1347 - val_accuracy: 0.9544
# Epoch 35/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.4621 - accuracy: 0.8591 - val_loss: 0.1269 - val_accuracy: 0.9576
# Epoch 36/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.4121 - accuracy: 0.8705 - val_loss: 0.1234 - val_accuracy: 0.9623
# Epoch 37/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.4191 - accuracy: 0.8492 - val_loss: 0.1163 - val_accuracy: 0.9630
# Epoch 38/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.3618 - accuracy: 0.8819 - val_loss: 0.1256 - val_accuracy: 0.9599
# Epoch 39/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.4097 - accuracy: 0.8616 - val_loss: 0.1268 - val_accuracy: 0.9595
# Epoch 40/40
# 7/7 [==============================] - 10s 2s/step - loss: 0.3818 - accuracy: 0.8817 - val_loss: 0.1179 - val_accuracy: 0.9606

# %%
# Plots for training and testing process: loss and accuracy

n_epochs = len(history.history['loss'])

plt.figure(0)
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Cat_Accuracy vs Validation Cat_Accuracy")
plt.legend(['train','validation'])

# %%
plt.figure(1)
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
plt.show()

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.11785662919282913
# Test accuracy: 0.9606000185012817

# %%
# evaluate loaded model
scores_train = model.evaluate(x_train, y_train, verbose=0)
scores_test  = model.evaluate(x_test,  y_test,  verbose=0)

print("Accuracy Train: %.2f%% , Test: %.2f%% " % (scores_train[1]*100, scores_test[1]*100 ))
# Out:
# Accuracy Train: 98.00% , Test: 96.06%

# %%
# Confusion matrix result

from sklearn.metrics import classification_report, confusion_matrix
Y_pred = model.predict(x_test, verbose=2)

y_pred = np.argmax(Y_pred, axis=1)

y_test2 = np.argmax(y_test, axis=1)



#confusion matrix
cm = confusion_matrix(np.argmax(y_test,axis=1),y_pred)
print(cm)
# Out:
# 313/313 - 8s
# [[ 975    0    2    0    0    0    0    1    1    1]
#  [   0 1108    2    4    0    2    1    4   14    0]
#  [   2    0 1004    1    2    1    0   15    7    0]
#  [   0    0    3  981    0    9    0    6    9    2]
#  [   1    0    1    0  911    0    9    2    4   54]
#  [   2    3    0   11    0  852    9    3   10    2]
#  [   6    6    0    0    2    5  936    0    3    0]
#  [   2    0   35    4    2    0    0  969    1   15]
#  [  19    1   11    0    4    3    3    2  912   19]
#  [  12    1    1    9    5   13    1    8    1  958]]

# %%
# Visualizing of confusion matrix
import seaborn as sn
import pandas  as pd


df_cm = pd.DataFrame(cm, range(10),range(10))
#                     range(num_classes),
#                  range(num_classes))
#plt.figure(figsize = (10,7))
plt.figure(2,figsize = (15,15) )
sn.set(font_scale=1.4) #for label size
sn.heatmap(df_cm, annot=True,annot_kws={"size": 12})# font size
plt.show()

# %%
# use the model to predict the labels of the test data
predicted = model.predict(x_test)
expected = y_test0



# Plot the prediction
fig = plt.figure(figsize=(20, 20))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)


# plot the digits: each image is 28x28 pixels
for i in range(400):
    ax = fig.add_subplot(20, 20, i + 1, xticks=[], yticks=[])
    ax.imshow(x_test[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')

    # label the image with the target value
    if np.argmax(predicted[i]) == expected[i]:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='green')
    else:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='red')

# %%
# Creates the graph.png file

! pip3 install keras-visualizer
from keras_visualizer import visualizer  

#create the graph.png image
visualizer(model=model, view=True, format='png', filename='graph')

#show the graph
import matplotlib.image as mpimg
img = mpimg.imread('graph.png')
imgplot = plt.imshow(img,)
plt.show()
# Out:
# Requirement already satisfied: keras-visualizer in /usr/local/lib/python3.6/dist-packages (2.4)
